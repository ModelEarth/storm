# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", palette="pastel")


### Perturbation Degree
# perturbation-only-one-norm-value.csv
#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/norm_and_impact/perturbation-chart-discrete-6-steps.csv")
tips = pd.read_csv("/Users/East/Data/TW-Charts/charts/data/perturbation-discrete-6-steps.csv")

ax = sns.boxplot(x="label", y="change_step_avg_degrees_abs",hue="label", palette=["c", "g", "b", "y", "r", "m"],data=tips)
ax.set_ylabel('Change in Displacement Distance (Lat/Lon Degrees) - Absolute',fontsize=24) # Perturbation Degree
ax.set_xlabel('Wind Speed (mph) - Storm - Impacted City',fontsize=20,labelpad=20)
ax.set(ylim=(0,.007))
#plt.setp(ax.get_xticklabels(), rotation=45)
#ax.setp(ax.get_xticklabels(), rotation=45)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45) # Rotate the x-labels
#sns.despine(offset=30, trim=False)

#sns.despine(offset=10, trim=True) # Hide surrounding box
ax.tick_params(labelsize=14)
#ax.xaxis.set_tick_params(which='majorX', pad=30)

# Add margin to bottom so labels are not cut-off.
#matplotlib.pyplot.subplots_adjust(bottom=_BOTTOM_MARGIN)

sns.set(rc={'figure.figsize':(24,14)}) # Run twice to see size, if not already set.

import matplotlib.pyplot as plt
plt.rc('axes.spines', **{'bottom':True, 'left':True, 'right':False, 'top':False})
