# %%
# Multiple distributions
# https://python-graph-gallery.com/25-histogram-with-several-variables-seaborn/

# USE THIS ONE with other page - FacetGrid <<<<<<<<<<
# https://tryolabs.com/blog/2017/03/16/pandas-seaborn-a-guide-to-handle-visualize-data-elegantly/

# Import library and dataset
import pandas as pd
#import os
import seaborn as sns
sns.set(style="ticks", palette="pastel")

#df = sns.load_dataset('iris')

# Method 1: on the same Axis
#sns.distplot( df["sepal_length"] , color="skyblue", label="Sepal Length")
#sns.distplot( df["sepal_width"] , color="red", label="Sepal Width")
#sns.plt.legend()

#sns.plt.show()


#by_cat_gen = df.groupby(['category','gender'])
#by_cat_gen.get_group(('Physics', 'female'))[['name', 'year']]

# Load csv to dataframe
df = pd.read_csv('/Users/East/Data/TW-Charts/seaborn/data/norm_and_impact/norm_and_impact.csv', index_col=0)
# Apply filter to a new dataset

newdf = df[df['isimpactday'] == "YES"]
sns.distplot(newdf.displacement)

#sns.distplot(df[df['isimpactday'] == "YES"].displacement)
#sns.distplot(df[df['isimpactday'] == "YES",df['city'] == "Tampa"].displacement)

sns.set(rc={'figure.figsize':(6.5,7.5)})


# Display on same graph after adding script from 25-histogram-with-several-variables-seaborn
df2 = pd.read_csv('/Users/East/Data/TW-Charts/seaborn/data/norm_and_impact/norm_and_impact.csv', index_col=0)

# Python query samples
# https://tryolabs.com/blog/2017/03/16/pandas-seaborn-a-guide-to-handle-visualize-data-elegantly/

sns.distplot(df2[df2['isimpactday'] != "YES"].displacement)
#sns.distplot(df2.displacement)
