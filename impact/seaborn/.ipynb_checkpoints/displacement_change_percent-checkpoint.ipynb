# %%
import pandas as pd
#import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", palette="pastel")

# step_type Yes No initially, then add the number.
# day (Fri, Sat, Sun) equivalent could be storm or day (impact and norm)
# palette would need to be increased to cover the number of storms

#sns.set(rc={'figure.figsize':(11.7,8.27)})
#sns.boxplot(x="day", y="displacement",hue="step_type", palette=["c", "g", "b", "y", "r", "m"],data=tips)

#ax.set_title('Typhoon Haiyan, Cebu City, 2013-11-08, 140 kph',fontsize=28)
#ax.set_title('Mangkhut, Hong Kong, 2018-09-15, 5 pm, 135 kph',fontsize=28)

### Radius of Gyration - One - Change to x="days3" to cluster boxplots by 3 day intervals
#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/gyration/ja2017_tokyo_gyration.csv")
#ax = sns.boxplot(x="days", y="radius_of_gyration",data=tips)
#ax.set_ylabel('Radius of Gyration (km)',fontsize=24)
#ax.set_xlabel('Days from Impact',fontsize=20)

### Radius of Gyration - All
#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/gyration/gyration.csv")
##sns.set(rc={'figure.figsize':(22,9)}) # Must proceed setting boxplot, else run twice to see effect.
##sns.set(style="whitegrid") #Adds horizontal lines, naw.
#ax = sns.boxplot(x="label", y="changegyrationpercent", hue="label", palette=["c", "g", "b", "y", "r", "m"], data=tips)
#ax.set_ylabel('Change in Radius of Gyration (%)',fontsize=24)
#ax.set_xlabel('',fontsize=20)
#ax.set(ylim=(-200,200))


### Daily Travel Distances (1,4,6) - Use with data/stepdiff/diff.csv
## y="change" or "thediff" or "diffPercent"
#ax = sns.boxplot(x="label", y="change", hue="step_type", palette=["c", "g", "b", "y", "r", "m"], data=tips)
#ax.set_ylabel('Diff Impact to Norm Displacements (%)',fontsize=24)
#ax.set_xlabel('',fontsize=20) # Impacted Cities (6 Steps)


#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/stepdiff/norm_impact_chart.csv")

# y="percentagechangedisplacement"
#ax = sns.boxplot(x="storm", y="changedisplacement", hue="step_type", palette=["c", "g", "b", "y", "r", "m"], data=tips)
#ax.set_ylabel('Displacement Diff within steps Impact to Norm (%)',fontsize=18)
#ax.set_xlabel('',fontsize=20) # Impacted Cities (6 Steps)

### Daily Travel Diff Percent - Best so far
#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/stepdiff/diff.csv") # best so far
## "thediff" or "diffPercent" (thediff drops almost equally below line. tails are all negative.)
#ax = sns.boxplot(x="label", y="diffpercent", hue="step_type", palette=["c", "g", "b", "y", "r", "m"], data=tips)
#ax.set_ylabel('Difference Impact to Norm Displacements (%)',fontsize=18)
#ax.set_xlabel('',fontsize=20) # Impacted Cities (6 Steps)

### Perturbation Degree - Moved to seaborn-perturbation
##tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/norm_and_impact/perturbation.csv")
## options: percentagechangedisplacement and percentagechangenorm (which is actually change from impact to norm)
#ax = sns.boxplot(x="label", y="percentagechangedisplacement",hue="label", palette=["c", "g", "b", "y", "r", "m"],data=tips)
#ax.set_ylabel('Change in Displacement (%)',fontsize=24) # Perturbation Degree - % Change in Displacement
#ax.set_xlabel('Impacted Cities and Wind Speed (mph)',fontsize=20,labelpad=20)
#ax.set(ylim=(-100,2200))
#plt.setp(ax.get_xticklabels(), rotation=90)
#sns.despine(offset=30, trim=False)

### Displacement Distance (no percent)
##tips = pd.read_csv("Tampa-ByDay-Local.csv")
##tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/p/all_p.csv")


##tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/norm_and_impact/perturbation-only-one-norm-value.csv")
## ax.set_ylabel('Change in Displacement (km)',fontsize=24) # Perturbation Degree - % Change in Displacement

tips = pd.read_csv("/Users/East/Data/TW-Charts/charts/data/perturbation-discrete-6-steps.csv")
# y="changedisplacement"
ax = sns.boxplot(x="label", y="change_step_displacement_percent",hue="label", palette=["c", "g", "b", "y", "r", "m"],data=tips)
ax.set_ylabel('Change in Displacement (percent) for 6-steps',fontsize=24) # Perturbation Degree - % Change in Displacement
ax.set_xlabel('Impacted Cities and Wind Speed (mph)',fontsize=20)
ax.set(ylim=(20,-100))

ax.set_xticklabels(ax.get_xticklabels(), rotation=45) # Rotate the x-labels

#sns.despine(offset=10, trim=True) # Hide surrounding box
ax.tick_params(labelsize=14)

# https://dustinoprea.com/2015/05/17/beautiful-python-charts-using-seaborn/
# Rotate the x-labels
#ax.set_xticklabels(labels, rotation=_ROTATION_DEGREES)
# Add some margin to the bottom so the labels aren't cut-off.
#matplotlib.pyplot.subplots_adjust(bottom=_BOTTOM_MARGIN)
 

#tips = pd.read_csv("/Users/East/Data/TW-Charts/seaborn/data/gyration/ph2013_cebu_city_31day_gyration.csv")
#sns.boxplot(x="days", data=tips)
# Draw a nested boxplot to show bills by day and time
#sns.boxplot(x="day", y="total_bill",
#            hue="smoker", palette=["m", "g"],
#            data=tips)

#sns.set(style="whitegrid") #Adds horizontal lines, naw.
#sns.set(rc={'figure.figsize':(18.7,9.5)}) # Radius of gyration
sns.set(rc={'figure.figsize':(24,9.5)}) # Run twice to see size, if not already set.
